# %% [markdown]
# ## Introduction to Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
plt.style.available # hien cac style co san
plt.style.use("seaborn-whitegrid")

# %%
plt.plot()
# Out:
# []

# %%
x = [1, 2, 3, 4]
y = [10, 8, 6, 9]
plt.plot(x, y, color = "green"); #put ; to remove([<matplotlib.lines.Line2D at 0x1d530cd1f10>])

# %% [markdown]
# ## Pyplot API vs Object-Oriented API
# * Pyplot API  -> Quickly
# * OOP API -> Advanced (phuc tap)

# %% [markdown]
# ## Pyplot API

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), color = "green", linestyle = "dashed", label = "sin(x)");
plt.plot(x, np.cos(x), color = "blue", label = "cos(x)")

plt.title("Sin(x) & Cos(x)") # dat titel cho do thi
plt.xlabel("X") # dat ten cho trc x
plt.ylabel("F(x)") # dat ten cho truc y

#plt.xlim([0,4]) # gioi han truc x theo khoang mong muon
#plt.ylim([- 0.6, 2]) # gioi ham truc y theo khoang mong muon
#plt.axis([0,4, -0.7, 0.6])#plt.axis([xmin, xmax, ymin, ymax]) gioi han
plt.axis("tight") # khít luôn
plt.axis("equal") # truc x, y bang nhau
plt.legend(); #call ham legend ra moi co dc

# %% [markdown]
# ##  Object-Oriented API

# %%
#1 prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2. Setup plot
fig, ax = plt.subplots(figsize = (5,5)) #figure seze = width and hight of the plot
# fig laf hinh tong
# ax la hinh nhor

#3. plot the data
ax.plot(x, y);

ax.set(title = "A simple plot",
       xlabel = "x-axis",
       ylabel = "y-axis");

# %% [markdown]
# ## 2. Most common types of Matplotlib plots
# * line
# * scatter
# * bar
# * hist
# * subplots()

# %% [markdown]
# ### Line

# %%
#creat an array
x = np.linspace(0,10,100)

# %%
#OO API plot a line chart
fig, ax = plt.subplots()
ax.plot(x, x**3);

# %% [markdown]
# ### Sactter

# %%
# Pyplot API
plt.scatter(x, np.exp(x));

# %%
# OO API
# Prepare New Data
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)

colors = rng.rand(100) # chon mau
sizes = 1000*rng.rand(100) # kich co cua cac cham tron

plt.rcParams["axes.grid"] = False #khong hien thi cai warning
fig, ax = plt.subplots()
img1 = ax.scatter(x, y, s = sizes, c = colors, cmap = "viridis", alpha = 0.3);
fig.colorbar(img1);

# %% [markdown]
# ### 3. Bar
# * Vertical: Cot dung
# * Horizontal: Cot ngang

# %%
#Prepare Data from a python dictionary
img2 = soft_drink_prices = {"Coke": 10,
                    "Pepsi": 12,
                    "Sprite": 8}

# %%
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax.set(title = "Bach hoa xanh's Soft Drink Prices", ylabel = "Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()),list(soft_drink_prices.values()));

# %% [markdown]
# ## Histogram

# %%
# prepare data
np.random.seed(42)
student_height = np.random.normal(170, 10, 250) #mean, std, total

# %%
student_height[:10]
# Out:
# array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#        167.65846625, 167.65863043, 185.79212816, 177.67434729,
#        165.30525614, 175.42560044])

# %%
#pyplot API
plt.hist(student_height,bins = 30, color = "green"); #bins: chia nho

# %% [markdown]
# ### subplots
# Multiple plots on one figure link: https://matplotlib.org/3.1.1/gallery/recipes/create_subplots.html

# %%
# Option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2,
                       ncols = 2,
                       figsize = (10, 5))
#plot data to each axis
ax1.plot(x, x/2);
ax1.plot(x, x*2)

ax2.scatter(np.random.rand(10), np.random.rand(10));

ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax4.hist(student_height,bins = 30, color = "green");

# %%
# option 2:
fig, ax = plt.subplots(nrows = 2,
                       ncols = 2,
                      figsize = (10,5))
#plot data to each axis
ax[0,0].plot(x, x/2);
ax[0,0].plot(x, x*2)

ax[0,1].scatter(np.random.rand(10), np.random.rand(10));

ax[1,0].bar(soft_drink_prices.keys(), soft_drink_prices.values());

ax[1,1].hist(student_height,bins = 30, color = "green");

# %% [markdown]
# # Creat Project: Visualization

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

cities = pd.read_csv("C:/Users/PC/CODE/PYTHON/Analytic Practice/Matplotlib/california_cities.csv")

# %%
cities.head()
cities["area_total_km2"].sort_values(ascending = False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
# Extract latitude & longtitude: Vĩ độ, Kinh độ
lat, lon = cities["latd"], cities["longd"]

population, area = cities["population_total"], cities["area_total_km2"]

# %%
#Plot using Pyplot API
#plt.rcParams['axes.grid'] = False
#plt.style.use("seaborn")
plt.figure(figsize = (8, 6))

plt.scatter(lon, lat, 
            c = np.log10(population),
            cmap = "viridis",
            s = area, linewidths = 0, alpha = 0.3); # màu cho dân số và size cho diện tích
plt.axis("equal")
plt.xlabel("longlatitude");
plt.ylabel("latitude");
plt.colorbar(label = "log$_{10}$(population)");
plt.clim(3, 7) # giới hạn thanh màu

# Create a legend for cities sizes: kích cỡ của từng thành phố 1
area_range = [50, 100, 300, 500]

# Tạo label: Chú thích
for area in area_range:
    plt.scatter([], [], s = area,
               label = str(area) + 'km$^2$',
                c = 'k', alpha = 0.4) #Không gán tọa độ, c = k chỉnh cùng màu
plt.legend( labelspacing = 1, title = "City area") # tạo chú thích

plt.title("California Cities: Population and Area Distribution");
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_18604\904939803.py:13: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(label = "log$_{10}$(population)");
